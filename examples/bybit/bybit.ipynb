# %%
import sys
sys.path.append('..')

from krex.bybit.client import Client

# %%
client = Client(api_key='VLOpq0qMKPNWhMbKVH', api_secret='Q3OKhzHiVSOYE2tF8ns2My4mQU7B8d5MnbOt')

# %% [markdown]
# ## market http

# %%
client.get_instruments_info(category="spot")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'spot',
#   'list': [{'symbol': 'BTCUSDT',
#     'baseCoin': 'BTC',
#     'quoteCoin': 'USDT',
#     'innovation': '0',
#     'status': 'Trading',
#     'marginTrading': 'utaOnly',
#     'stTag': '0',
#     'lotSizeFilter': {'basePrecision': '0.000001',
#      'quotePrecision': '0.00000001',
#      'minOrderQty': '0.000011',
#      'maxOrderQty': '83',
#      'minOrderAmt': '5',
#      'maxOrderAmt': '8000000'},
#     'priceFilter': {'tickSize': '0.01'},
#     'riskParameters': {'priceLimitRatioX': '0.01',
#      'priceLimitRatioY': '0.02'}},
#    {'symbol': 'ETHUSDT',
#     'baseCoin': 'ETH',
#     'quoteCoin': 'USDT',
#     'innovation': '0',
#     'status': 'Trading',
#     'marginTrading': 'utaOnly',
#     'stTag': '0',
#     'lotSizeFilter': {'basePrecision': '0.00001',
#      'quotePrecision': '0.0000001',
#      'minOrderQty': '0.00029',
#      'maxOrderQty': '3070.458244',
#      'minOrderAmt': '5',
# ...

# %%
client.get_kline(symbol="BTCUSD", interval="1")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'symbol': 'BTCUSD',
#   'category': '',
#   'list': [['1741865580000',
#     '82895.5',
#     '82905',
#     '82883',
#     '82894.5',
#     '156143',
#     '1.88353036'],
#    ['1741865520000',
#     '82862.5',
#     '82909',
#     '82841',
#     '82895.5',
#     '176139',
#     '2.12558612'],
#    ['1741865460000',
#     '82823',
#     '82891',
#     '82823',
#     '82862.5',
#     '84438',
#     '1.01896254'],
#    ['1741865400000',
#     '82790',
#     '82823',
#     '82779',
#     '82823',
#     '148850',
#     '1.79741995'],
#    ['1741865340000',
#     '82740.5',
#     '82791',
#     '82740',
#     '82790',
#     '12842',
#     '0.15514825'],
#    ['1741865280000',
#     '82738.5',
#     '82763',
#     '82725',
#     '82740.5',
#     '152625',
#     '1.84451346'],
#    ['1741865220000',
#     '82818',
#     '82818',
#     '82717',
#     '82738.5',
#     '193892',
#     '2.34311377'],
#    ['1741865160000',
#     '82828.5',
# ...

# %%
client.get_orderbook(category="spot", symbol="BTCUSDT")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'s': 'BTCUSDT',
#   'a': [['83007.81', '0.893142']],
#   'b': [['83007.8', '0.227582']],
#   'ts': 1741865676009,
#   'u': 6130105,
#   'seq': 66426617165,
#   'cts': 1741865676004},
#  'retExtInfo': {},
#  'time': 1741865676158}

# %%
client.get_tickers(category="spot")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'spot',
#   'list': [{'symbol': 'LDOUSDC',
#     'bid1Price': '0.915',
#     'bid1Size': '437.18',
#     'ask1Price': '0.916',
#     'ask1Size': '0.94',
#     'lastPrice': '0.916',
#     'prevPrice24h': '0.923',
#     'price24hPcnt': '-0.0076',
#     'highPrice24h': '0.9587',
#     'lowPrice24h': '0.873',
#     'turnover24h': '55251.788306',
#     'volume24h': '61240.15',
#     'usdIndexPrice': '0.91563'},
#    {'symbol': 'BONKUSDC',
#     'bid1Price': '0.00001074',
#     'bid1Size': '27466111',
#     'ask1Price': '0.00001077',
#     'ask1Size': '38392943',
#     'lastPrice': '0.0000107',
#     'prevPrice24h': '0.00001044',
#     'price24hPcnt': '0.0249',
#     'highPrice24h': '0.00001092',
#     'lowPrice24h': '0.00001007',
#     'turnover24h': '27999.2848274',
#     'volume24h': '2647308275',
#     'usdIndexPrice': '0.0000107474'},
#    {'symbol': 'BLOCKUSDT',
#     'bid1Price': '0.003142',
#     'bid1Size': '4542.89',
# ...

# %%
client.get_funding_rate_history(category="linear", symbol="BTCUSD")
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'category': 'linear',
#   'list': [{'symbol': 'BTCUSD',
#     'fundingRate': '0.00009081',
#     'fundingRateTimestamp': '1741852800000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.00001691',
#     'fundingRateTimestamp': '1741824000000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.00003436',
#     'fundingRateTimestamp': '1741795200000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.00005743',
#     'fundingRateTimestamp': '1741766400000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.0000007',
#     'fundingRateTimestamp': '1741737600000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1741708800000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1741680000000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.0001',
#     'fundingRateTimestamp': '1741651200000'},
#    {'symbol': 'BTCUSD',
#     'fundingRate': '0.00008066',
# ...

# %% [markdown]
# ## account http

# %%
client.get_wallet_balance()
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'list': [{'totalEquity': '26.47768224',
#     'accountIMRate': '0',
#     'totalMarginBalance': '26.47768224',
#     'totalInitialMargin': '0',
#     'accountType': 'UNIFIED',
#     'totalAvailableBalance': '26.47768224',
#     'accountMMRate': '0',
#     'totalPerpUPL': '0',
#     'totalWalletBalance': '26.47768224',
#     'accountLTV': '0',
#     'totalMaintenanceMargin': '0',
#     'coin': [{'availableToBorrow': '',
#       'bonus': '0',
#       'accruedInterest': '0',
#       'availableToWithdraw': '',
#       'totalOrderIM': '0',
#       'equity': '26.4838',
#       'totalPositionMM': '0',
#       'usdValue': '26.47768224',
#       'unrealisedPnl': '0',
#       'collateralSwitch': True,
#       'spotHedgingQty': '0',
#       'borrowAmount': '0.000000000000000000',
#       'totalPositionIM': '0',
#       'walletBalance': '26.4838',
#       'cumRealisedPnl': '0',
#       'locked': '0',
#       'marginCollateral': True,
# ...

# %%
client.get_transferable_amount(['USDT'])
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'availableWithdrawal': '27.48380000',
#   'availableWithdrawalMap': {'USDT': '27.48380000'}},
#  'retExtInfo': {},
#  'time': 1741797065232}

# %%
client.upgrade_to_unified_trading_account()
# Out:
# {'retCode': 0,
#  'retMsg': 'SUCCESS',
#  'result': {'unifiedUpdateStatus': 'SUCCESS', 'unifiedUpdateMsg': None},
#  'retExtInfo': {},
#  'time': 1741797077994}

# %%
client.get_borrow_history()
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': None, 'list': []},
#  'retExtInfo': {},
#  'time': 1741797089106}

# %%
client.repay_liability()
# Out:
# {'retCode': 182102,
#  'retMsg': 'Failed repayment, there are no liabilities in the current currency.',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1741797107694}

# %%
client.get_collateral_info()
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'list': [{'availableToBorrow': '100',
#     'freeBorrowingAmount': '',
#     'freeBorrowAmount': '0',
#     'maxBorrowingAmount': '100',
#     'hourlyBorrowRate': '0.00000125',
#     'borrowUsageRate': '0',
#     'collateralSwitch': False,
#     'borrowAmount': '0',
#     'borrowable': True,
#     'currency': 'BTC',
#     'otherBorrowAmount': '0',
#     'marginCollateral': True,
#     'freeBorrowingLimit': '0',
#     'collateralRatio': '0.98'},
#    {'availableToBorrow': '800',
#     'freeBorrowingAmount': '',
#     'freeBorrowAmount': '0',
#     'maxBorrowingAmount': '800',
#     'hourlyBorrowRate': '0.00000232',
#     'borrowUsageRate': '0',
#     'collateralSwitch': False,
#     'borrowAmount': '0',
#     'borrowable': True,
#     'currency': 'ETH',
#     'otherBorrowAmount': '0',
#     'marginCollateral': True,
#     'freeBorrowingLimit': '0',
#     'collateralRatio': '0.95'},
#    {'availableToBorrow': '374500',
# ...

# %%
client.set_collateral_coin('BTC', 'ON')
# Out:
# {'retCode': 0,
#  'retMsg': 'SUCCESS',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1741797294579}

# %%
client.get_fee_rates('linear')
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'list': [{'symbol': 'SNTUSDT',
#     'takerFeeRate': '0.00055',
#     'makerFeeRate': '0.0002'},
#    {'symbol': 'VELODROMEUSDT',
#     'takerFeeRate': '0.00055',
#     'makerFeeRate': '0.0002'},
#    {'symbol': 'YGGUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'GASUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'NKNUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'CVCUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'ARKUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'GMEUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'BANDUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'XRPPERP', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
#    {'symbol': 'PHBUSDT', 'takerFeeRate': '0.00055', 'makerFeeRate': '0.0002'},
# ...

# %%
client.get_account_info()
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'marginMode': 'REGULAR_MARGIN',
#   'updatedTime': '1741305977000',
#   'unifiedMarginStatus': 6,
#   'dcpStatus': 'OFF',
#   'timeWindow': 0,
#   'smpGroup': 0,
#   'isMasterTrader': False,
#   'spotHedgingStatus': 'OFF'}}

# %%
client.get_transaction_log()
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': '3894%3A0%2C30%3A0',
#   'list': [{'symbol': '',
#     'side': 'None',
#     'funding': '0',
#     'orderLinkId': '',
#     'orderId': '',
#     'fee': '0',
#     'change': '27.4838',
#     'cashFlow': '27.4838',
#     'transactionTime': '1741766015439',
#     'type': 'TRANSFER_IN',
#     'feeRate': '0',
#     'bonusChange': '0',
#     'size': '0',
#     'qty': '0',
#     'cashBalance': '27.4838',
#     'currency': 'USDT',
#     'id': '439606179-439606180-a00d5a06-3038-4727-a0d7-02458b83281b',
#     'category': '',
#     'tradePrice': '0',
#     'tradeId': ''},
#    {'symbol': '',
#     'side': 'None',
#     'funding': '0',
#     'orderLinkId': '',
#     'orderId': '',
#     'fee': '0',
#     'change': '-27.4838',
#     'cashFlow': '-27.4838',
#     'transactionTime': '1741765713051',
#     'type': 'TRANSFER_OUT',
#     'feeRate': '0',
#     'bonusChange': '',
#     'size': '0',
#     'qty': '0',
# ...

# %%
client.set_margin_mode('PORTFOLIO_MARGIN')
# Out:
# {'retCode': 110073,
#  'retMsg': 'Set margin mode failed',
#  'result': {'reasons': [{'reasonCode': '3400100',
#     'reasonMsg': 'Asset requirements not met.'}]}}

# %% [markdown]
# ## asset http

# %%
client.get_coin_info()
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'rows': [{'name': '1INCH',
#     'coin': '1INCH',
#     'remainAmount': '415000',
#     'chains': [{'chainType': 'Ethereum',
#       'confirmation': '6',
#       'withdrawFee': '20',
#       'depositMin': '0',
#       'withdrawMin': '20',
#       'chain': 'ETH',
#       'chainDeposit': '1',
#       'chainWithdraw': '1',
#       'minAccuracy': '8',
#       'withdrawPercentageFee': '0',
#       'contractAddress': '0x111111111117dc0aa78b770fa6a738034120c302'}]},
#    {'name': '1SOL',
#     'coin': '1SOL',
#     'remainAmount': '1000000',
#     'chains': [{'chainType': 'SOL',
#       'confirmation': '200',
#       'withdrawFee': '100',
#       'depositMin': '0',
#       'withdrawMin': '100',
#       'chain': 'SOL',
#       'chainDeposit': '1',
#       'chainWithdraw': '1',
#       'minAccuracy': '8',
#       'withdrawPercentageFee': '0',
#       'contractAddress': '4ThReWAbAVZjNVgs5Ui9Pk3cZ5TYaD9u6Y89fp6EFzoF'}]},
#    {'name': '3P',
# ...

# %%
client.get_sub_uid()
# Out:
# {'retCode': 10005,
#  'retMsg': 'Permission denied, please check your API key permissions.',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1741798101765}

# %%
client.get_spot_asset_info()
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'spot': {'status': 'ACCOUNT_STATUS_NORMAL', 'assets': []}},
#  'retExtInfo': {},
#  'time': 1741798121167}

# %%
client.get_coins_balance('FUND')
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'memberId': '439606179',
#   'accountType': 'FUND',
#   'balance': [{'coin': 'USDT',
#     'transferBalance': '0',
#     'walletBalance': '0',
#     'bonus': ''}]},
#  'retExtInfo': {},
#  'time': 1741798234613}

# %%
client.get_coin_balance('FUND', 'BTC')
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'accountType': 'FUND',
#   'bizType': 1,
#   'accountId': '439606243',
#   'memberId': '439606179',
#   'balance': {'coin': 'BTC',
#    'walletBalance': '0',
#    'transferBalance': '0',
#    'bonus': '0',
#    'transferSafeAmount': '',
#    'ltvTransferSafeAmount': ''}},
#  'retExtInfo': {},
#  'time': 1741798257005}

# %%
client.get_withdrawable_amount('USDT')
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'limitAmountUsd': '0',
#   'withdrawableAmount': {'FUND': {'coin': 'USDT',
#     'withdrawableAmount': '0',
#     'availableBalance': '0'}}},
#  'retExtInfo': {},
#  'time': 1741798276575}

# %%
client.get_internal_transfer_records()
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'list': [{'transferId': '3e78da18-887e-434a-b4bb-6dbf7b1501a5',
#     'coin': 'USDT',
#     'amount': '27.4838',
#     'fromAccountType': 'FUND',
#     'toAccountType': 'UNIFIED',
#     'timestamp': '1741766015000',
#     'status': 'SUCCESS'},
#    {'transferId': 'selfTransfer_532c7244-08bb-4b37-a804-29e85d8d1244',
#     'coin': 'USDT',
#     'amount': '27.4838',
#     'fromAccountType': 'UNIFIED',
#     'toAccountType': 'FUND',
#     'timestamp': '1741765713000',
#     'status': 'SUCCESS'}],
#   'nextPageCursor': 'eyJtaW5JRCI6MTkxNzQxNzY1NzEyOTQyMjI3NSwibWF4SUQiOjE5MTc0MTc2NjAxNTM0MjIzNDF9'},
#  'retExtInfo': {},
#  'time': 1741798294437}

# %%
client.get_transferable_coin('FUND', 'UNIFIED')
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'list': ['BTC',
#    'ETH',
#    'USDT',
#    'HMSTR',
#    'USDC',
#    'XRP',
#    'TRX',
#    'MNT',
#    'SOL',
#    'X',
#    '1INCH',
#    '1SOL',
#    '3P',
#    '5IRE',
#    'A8',
#    'AARK',
#    'AAVE',
#    'ACA',
#    'ACH',
#    'ACS',
#    'ADA',
#    'AEG',
#    'AERO',
#    'AEVO',
#    'AFC',
#    'AFG',
#    'AGI',
#    'AGLA',
#    'AGLD',
#    'AI16Z',
#    'AIDOGE',
#    'AIOZ',
#    'AITECH',
#    'AIXBT',
#    'AKI',
#    'ALCH',
#    'ALEO',
#    'ALGO',
#    'ALI',
#    'ALT',
#    'ANIME',
#    'ANKR',
#    'ANTEX',
#    'APE',
#    'APEX',
#    'APP',
#    'APRS',
#    'APT',
#    'APTR',
#    'AR',
#    'ARB',
#    'ARIES',
#    'ARKM',
#    'ARTY',
#    'ATH',
#    'ATOM',
#    'AURORA',
#    'AURY',
#    'AVA',
#    'AVAIL',
#    'AVAOLD',
#    'AVAX',
#    'AVL',
#    'AXL',
#    'AXS',
#    'B2',
#    'B3',
#    'BABY',
#    'BABYDOGE',
#    'BAN',
#    'BANA',
#    'BAT',
#    'BB',
#    'BBL',
# ...

# %%
client.create_internal_transfer('USDT', '1', 'UNIFIED', 'FUND')
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'transferId': '9c2b4274-ba93-48b7-8c9b-3faba8980be5',
#   'status': 'SUCCESS'},
#  'retExtInfo': {},
#  'time': 1741798389333}

# %%
# not yet tested
client.create_universal_transfer()

# %%
# not yet tested
client.get_universal_transfer_records()

# %%
client.get_allowed_deposit_coin_info()
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'configList': [{'coin': 'BTC',
#     'chain': 'BTC',
#     'coinShowName': 'BTC',
#     'chainType': 'BTC',
#     'blockConfirmNumber': 1,
#     'minDepositAmount': '0.000006'},
#    {'coin': 'EOS',
#     'chain': 'EOS',
#     'coinShowName': 'EOS',
#     'chainType': 'EOS',
#     'blockConfirmNumber': 1,
#     'minDepositAmount': '0'},
#    {'coin': 'ETH',
#     'chain': 'ETH',
#     'coinShowName': 'ETH',
#     'chainType': '',
#     'blockConfirmNumber': 6,
#     'minDepositAmount': '0'},
#    {'coin': 'XRP',
#     'chain': 'XRP',
#     'coinShowName': 'XRP',
#     'chainType': 'XRP',
#     'blockConfirmNumber': 1,
#     'minDepositAmount': '0.01'},
#    {'coin': 'USDT',
#     'chain': 'ETH',
#     'coinShowName': 'USDT',
#     'chainType': '',
#     'blockConfirmNumber': 6,
#     'minDepositAmount': '0'},
#    {'coin': 'USDT',
#     'chain': 'TRX',
#     'coinShowName': 'USDT',
#     'chainType': 'TRC20',
# ...

# %%
client.get_deposit_records()
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'rows': [], 'nextPageCursor': ''},
#  'retExtInfo': {},
#  'time': 1741798650389}

# %%
client.get_sub_deposit_records()
# Out:
# {'retCode': 131002,
#  'retMsg': 'Sub Account ID cannot be 0 or nil',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1741798677632}

# %%
client.get_master_deposit_address('USDT')
# Out:
# {'retCode': 131003,
#  'retMsg': 'Not Support Sub Account',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1741798846147}

# %%
# not yet tested
client.get_sub_deposit_address()

# %%
client.get_withdrawal_records()
# Out:
# {'retCode': 0,
#  'retMsg': 'success',
#  'result': {'rows': [], 'nextPageCursor': ''},
#  'retExtInfo': {},
#  'time': 1741798869311}

# %%
client.get_positions('linear', settleCoin='USDT')
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {'nextPageCursor': '', 'category': 'linear', 'list': []},
#  'retExtInfo': {},
#  'time': 1741799375238}

# %%
client.set_leverage('linear', 'BTCUSDT', '20')
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1741799534997}

# %%
client.switch_position_mode(0, 'BTCUSDT')
# Out:
# {'retCode': 0,
#  'retMsg': 'OK',
#  'result': {},
#  'retExtInfo': {},
#  'time': 1741799604603}
